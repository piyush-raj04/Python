# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush-raj04/Python/blob/main/Pandas_working_withhtml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas working with HTML

# %%
import pandas as pd

# %%
import requests

url = "https://en.wikipedia.org/wiki/Mobile_country_code"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

response = requests.get(url, headers=headers)
html=pd.read_html(response.text)
# Out:
# /tmp/ipykernel_753/3288757203.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   html=pd.read_html(response.text)

# %%
type(html)
# Out:
# list

# %%
html[1]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
import requests

url = "https://en.wikipedia.org/wiki/Economy_of_the_United_States"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

response = requests.get(url, headers=headers)
html = pd.read_html(response.text, match="Government debt")
# Out:
# /tmp/ipykernel_753/631750130.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   html = pd.read_html(response.text, match="Government debt")

# %%
type(html)
# Out:
# list

# %%
html[0]
# Out:
#                                                     0  \
# 0   The nation's largest city, New York City, is c...
# 1                                            Currency
# 2                                         Fiscal year
# 3                                 Trade organizations
# 4                                       Country group
# 5                                          Statistics
# 6                                          Population
# 7                                                 GDP
# 8                                            GDP rank
# 9                                          GDP growth
# 10                                     GDP per capita
# 11                                GDP per capita rank
# 12                              GDP per capita growth
# 13                                      GDP by sector
# 14                                   GDP by component
# 15                                    Inflation (CPI)
# ...

# %%
import requests

url = "https://en.wikipedia.org/wiki/Minnesota"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

response = requests.get(url, headers=headers)
html=pd.read_html(response.text,match="Average daily maximum and minimum temperatures for selected cities in Minnesota")
# Out:
# /tmp/ipykernel_753/3557347058.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   html=pd.read_html(response.text,match="Average daily maximum and minimum temperatures for selected cities in Minnesota")

# %%
html[0]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
type(html[0])
# Out:
# pandas.core.frame.DataFrame

# %%
html[0].to_html('demo.html')
