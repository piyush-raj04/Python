# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush-raj04/Python/blob/main/Python_Data_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Data classes
#
# In Python, the dataclass decorator is a feature introduced in Python 3.7 that provides a concise way to define classes primarily intended to store data. It automatically generates several special methods, such as init, repr, and eq, based on the class attributes you define. This simplifies the process of creating and working with data-focused classes.

# %%
from dataclasses import dataclass

@dataclass
class Person:
  name:str
  age:int
  profession:str

# %% [markdown]
# The @dataclass decorator automatically generates the following methods for you:
#
# 1.init(): Initializes the object and assigns the provided values to the attributes.
#
# 2.repr(): Provides a string representation of the object.
#
# 3.eq(): Implements equality comparison between two objects of the class based on their attributes.

# %%
person1=Person('krish',17,'SE')
person1
# Out:
# Person(name='krish', age=17, profession='SE')

# %%
person1.age
# Out:
# 17

# %%
@dataclass
class Rectangle:
    width:int
    height:int
    color:str='white'

rectangle1=Rectangle(12,14)
rectangle2=Rectangle(13,14,'red')

# %%
rectangle2.color
# Out:
# 'red'

# %%
@dataclass(frozen=True)
class Point:
    x:int
    y:int

# %%
point=Point(12,14)
point.x,point.y
# Out:
# (12, 14)

# %%
point.x=13
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# /tmp/ipykernel_2033/616271061.py in <cell line: 0>()
# ----> 1 point.x=13
#
# <string> in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'x'

# %%
##inhertiance

@dataclass
class Person:
    name:str
    age:int

@dataclass
class Employee(Person):
    employee_id:str
    department:str

# %%
person=Person('Krish',31)
empolyee=Employee("krish",31,'123','AI')

# %%
empolyee.name
# Out:
# 'krish'

# %%
##nested Dataclass:
@dataclass
class Address:
  street:str
  city:str
  state:str
  zip_code:str

@dataclass
class Person:
  name:str
  age:int
  address:Address

# %%
address=Address('123 Main St','New York','NY','10001')
person=Person('Krish',31,address)

# %%
person.address
# Out:
# Address(street='123 Main St', city='New York', state='NY', zip_code='10001')
