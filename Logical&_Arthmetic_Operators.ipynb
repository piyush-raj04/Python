# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush-raj04/Python/blob/main/Logical%26_Arthmetic_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Logical opreator and arthmetic operator

# %%
age=int(input("Enter the age"))
if age>18 and age>=35:
  print("sucessful execution")
# Out:
# Enter the age45
# sucessful execution

# %%
a="piyush"
b="piyush"

a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
age=int(input("enter the age"))
if age==18:
  print("you r in the teenager age")
# Out:
# enter the age14

# %%
ist=[1,2,3]
ist1=[1,2,3]
print(id(ist))
print(id(ist1))
# Out:
# 133839784467520
# 133839784476288

# %%
ist is ist1
# Out:
# False

# %%
ist is not ist1
# Out:
# True

# %%
marks=float(input("Enter the marks"))

if marks>=35:
  print("pass")
  if marks>=50 and marks<=70:
   print("first")
elif marks<35:
  print("fail")
# Out:
# Enter the marks55
# pass
# first

# %%
24+24
# Out:
# 48

# %%
48-24
# Out:
# 24

# %%
48/4
# Out:
# 12.0

# %%
48//9
# Out:
# 5
